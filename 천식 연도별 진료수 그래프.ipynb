# %%
import os
import pandas as pd
os.chdir(r"/Users/yeji/SWING 2023 해커톤 with LONDON/전처리데이터/연도별")

# %% [markdown]
# ## 천식 전체연령 연도별 진료수

# %%
import pandas as pd
month_df=pd.read_csv("천식_전체연령군_연월별진료수.csv")

# %%
month_df
# Out:
#          년월    진료수
# 0    201001  49983
# 1    201002  45500
# 2    201003  64592
# 3    201004  74404
# 4    201005  69281
# ..      ...    ...
# 139  202108  13863
# 140  202109  18955
# 141  202110  21344
# 142  202111  26901
# 143  202112  21416
#
# [144 rows x 2 columns]

# %%
month_df = month_df.astype({'년월':'string'})
month_df
# Out:
#          년월    진료수
# 0    201001  49983
# 1    201002  45500
# 2    201003  64592
# 3    201004  74404
# 4    201005  69281
# ..      ...    ...
# 139  202108  13863
# 140  202109  18955
# 141  202110  21344
# 142  202111  26901
# 143  202112  21416
#
# [144 rows x 2 columns]

# %%
month_df["월"]=month_df["년월"].str[4:]
month_df["년도"]=month_df["년월"].str[0:4]

# %%
month_df
# Out:
#          년월    진료수   월    년도
# 0    201001  49983  01  2010
# 1    201002  45500  02  2010
# 2    201003  64592  03  2010
# 3    201004  74404  04  2010
# 4    201005  69281  05  2010
# ..      ...    ...  ..   ...
# 139  202108  13863  08  2021
# 140  202109  18955  09  2021
# 141  202110  21344  10  2021
# 142  202111  26901  11  2021
# 143  202112  21416  12  2021
#
# [144 rows x 4 columns]

# %%
month_df=month_df.drop(['월'],axis=1)

# %%
month_df=month_df.drop(['년월'],axis=1)

# %%
month_df
# Out:
#        진료수    년도
# 0    49983  2010
# 1    45500  2010
# 2    64592  2010
# 3    74404  2010
# 4    69281  2010
# ..     ...   ...
# 139  13863  2021
# 140  18955  2021
# 141  21344  2021
# 142  26901  2021
# 143  21416  2021
#
# [144 rows x 2 columns]

# %%
month_df=month_df.groupby(['년도'], as_index=False).sum()

# %%
month_df
# Out:
#       년도     진료수
# 0   2010  719258
# 1   2011  713629
# 2   2012  698380
# 3   2013  665720
# 4   2014  664422
# 5   2015  602414
# 6   2016  614390
# 7   2017  527724
# 8   2018  529738
# 9   2019  506162
# 10  2020  256606
# 11  2021  224859

# %%
month_df.to_csv('/Users/yeji/SWING 2023 해커톤 with LONDON/전처리데이터/연도별/전체천식연도별.csv') #csv파일로 생성

# %%
import numpy as np
import matplotlib.pyplot as plt
#연도별 진료수 그래프

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

month_df.plot.bar(x='년도', y='진료수', rot=0,legend=False)
plt.title('12개년 천식 진료수')
plt.xlabel('년도')
plt.ylabel('진료수 합')
plt.show()

# %% [markdown]
# ## 천식 연령군 5의 연도별 진료수

# %%
import pandas as pd
fivemonth_df=pd.read_csv("천식_5연령군_연월별진료수.csv")

# %%
fivemonth_df
# Out:
#          년월   진료수
# 0    201001  7372
# 1    201002  6794
# 2    201003  7719
# 3    201004  8708
# 4    201005  8471
# ..      ...   ...
# 139  202108  4438
# 140  202109  4690
# 141  202110  5162
# 142  202111  5612
# 143  202112  5787
#
# [144 rows x 2 columns]

# %%
fivemonth_df = fivemonth_df.astype({'년월':'string'})
fivemonth_df
# Out:
#          년월   진료수
# 0    201001  7372
# 1    201002  6794
# 2    201003  7719
# 3    201004  8708
# 4    201005  8471
# ..      ...   ...
# 139  202108  4438
# 140  202109  4690
# 141  202110  5162
# 142  202111  5612
# 143  202112  5787
#
# [144 rows x 2 columns]

# %%
fivemonth_df["월"]=fivemonth_df["년월"].str[4:]
fivemonth_df["년도"]=fivemonth_df["년월"].str[0:4]

# %%
fivemonth_df=fivemonth_df.drop(['월'],axis=1)

# %%
fivemonth_df=fivemonth_df.drop(['년월'],axis=1)

# %%
fivemonth_df
# Out:
#       진료수    년도
# 0    7372  2010
# 1    6794  2010
# 2    7719  2010
# 3    8708  2010
# 4    8471  2010
# ..    ...   ...
# 139  4438  2021
# 140  4690  2021
# 141  5162  2021
# 142  5612  2021
# 143  5787  2021
#
# [144 rows x 2 columns]

# %%
fivemonth_df=fivemonth_df.groupby(['년도'], as_index=False).sum()

# %%
fivemonth_df
# Out:
#       년도     진료수
# 0   2010   91102
# 1   2011   93890
# 2   2012  105153
# 3   2013  105022
# 4   2014  106068
# 5   2015   99071
# 6   2016  101154
# 7   2017   96603
# 8   2018  105697
# 9   2019  104282
# 10  2020   70023
# 11  2021   58771

# %%
fivemonth_df.to_csv('/Users/yeji/SWING 2023 해커톤 with LONDON/전처리데이터/연도별/연령군5천식연도별.csv') #csv파일로 생성

# %%
import numpy as np
import matplotlib.pyplot as plt
#연도별 진료수 그래프

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

fivemonth_df.plot.bar(x='년도', y='진료수', rot=0,legend=False)
plt.title('12개년 연령군 5의 천식 진료수')
plt.xlabel('년도')
plt.ylabel('진료수 합')
plt.show()
