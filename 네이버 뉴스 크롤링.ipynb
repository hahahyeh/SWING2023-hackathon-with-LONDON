# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\sm\anaconda3\lib\site-packages (4.59.0)

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import os
import pandas as pd
import numpy as np
os.getcwd() #현재 경로 확인
os.chdir('C:\\Users\\SM\\Desktop\\YunJaeEun\\2023-2\\SWING')

# %%
df = pd.DataFrame([[0, 1, 2]],
                 columns = ['년도', '월', '제목'])

# %%
def ex_title(date,page):
    ### 뉴스 분야(sid)와 페이지(page)를 입력하면 그에 대한 링크들을 리스트로 추출하는 함수 ###
    
    ## 1.
    url = f"https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=102&sid2=252&date={date}&page={page}"
    html = requests.get(url, headers={"User-Agent": "Mozilla/5.0"\
    "(Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "\
    "Chrome/110.0.0.0 Safari/537.36"})
    soup = BeautifulSoup(html.text, "lxml")
    a_tag = soup.find_all("a")
    
    ## 2.
    title_lst = []
    for a in a_tag:
        if "href" in a.attrs:  # href가 있는것만 고르는 것
            if ("sid=102" in a["href"]) and ("article" in a["href"]) and ("<img alt" not in str(a)) and ("class" not in str(a)):
                title = str(a)[82:-13]
                year = int(str(date)[:4])
                month = int(str(date)[4:6])
                df.append([year, month, title])
                print([year, month, title])
                title_lst.append(title)
                
    return title_lst

# %%
for year in range(2010, 2022):
    for month in range(1, 13):
        for day in range(1, 29):
            date = str(year)+str(month).zfill(2)+str(day).zfill(2)
            date = int(date)
            for page in range(1, 10):
                ex_title(date, page)
# Out:
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, '서울시, 친환경 노면전차 도입 나선다']
# [2010, 1, '‘짙은 녹색주의’ 없는 기후대책은 재앙']
# [2010, 1, '발은 가려 딛고 눈은 천지를 뛰어 다니네']
# [2010, 1, '&lt;주말날씨&gt; 주말 눈 휴일 강추위']
# [2010, 1, '中, 야생호랑이 보호조치 실시']
# [2010, 1, '새해 첫 출근길 눈이나 비 내린다']
# [2010, 1, "`녹색성장 이끈다' 한국환경공단 출범"]
# [2010, 1, '메뚜기 등반대']
# [2010, 1, '메뚜기 한줄서기']
# [2010, 1, '저도 메뚜기래요']
# [2010, 1, '보호색과 메뚜기']
# [2010, 1, '&lt;내일날씨&gt; 추위 풀려 낮 기온 영상권']
# [2010, 1, '풀 반 메뚜기 반']
# [2010, 1, '‘송도 갯벌’ 습지 보호구역 지정']
# [2010, 1, '[날씨_1일(금)] 서해안 눈 내려요']
# [2010, 1, '백운아, 白虎 2세 부탁해!']
# [2010, 1, '전북 4개 시.군 19시 강풍주의보 해제']
# [2010, 1, '세밑 한파 이어… 새해 연휴도 강추위']
# [2010, 1, '일산~부천 부산~마산 복선전철 생긴다']
# [2010, 1, '강변북로 양화~원효대교 구간에 지하터널']
# [2010, 1, "전북, 경인년 새해 기온 '뚝'"]
# [2010, 1, '산천어 축제장 제설작업 한창']
# [2010, 1, '산천어 얼음낚시터 천공작업 한창']
# [2010, 1, '눈사람을 만들었어요']
# [2010, 1, '눈사람을 만들어요']
# [2010, 1, '빙어낚시 삼매경에 빠진 신혼부부']
# [2010, 1, '신혼의 즐거움을 즐기는 부부']
# [2010, 1, '아기고래 엄마고래']
# [2010, 1, '겨울광장을 찾은 백곰']
# [2010, 1, '겨울광장의 비너스']
# [2010, 1, '눈싸움의 즐거움에 동심으로...']
# [2010, 1, '눈이 오면 즐거워요!']
# [2010, 1, '게섯거라!']
# [2010, 1, '휴일 썰매타는 가족들']
# [2010, 1, '아이 차가워!']
# [2010, 1, '밤새 내린 눈 쓸어내는 새해 연휴']
# [2010, 1, '눈길 조심.. 조심..']
# [2010, 1, '한겨울 운치 전하는 눈내린 인도']
# [2010, 1, '한겨울의 운치 전하는 새해에 쌓인 눈']
# [2010, 1, '새해 아침에 대나무에 쌓인 눈']
# [2010, 1, '인사동의 겨울풍경']
# [2010, 1, '눈내린 인사동의 거리풍경']
# [2010, 1, '인사동 한옥에 쌓인 눈']
# [2010, 1, '새해 아침 대나무에 쌓인 눈']
# [2010, 1, '한겨울 운치 전하는 인사동 한옥']
# [2010, 1, '인사동의 한 민가에 매달린 까치밥']
# [2010, 1, '눈내린 아침 인사동에 매달린 까치밥']
# [2010, 1, '흰백의 눈과 어우러진 까치밥']
# [2010, 1, '하얀 세상으로 시작하는 새해']
# [2010, 1, '눈 내린 주차장']
# [2010, 1, '흰 눈이 왔어요']
# [2010, 1, '눈길엔 서행하세요']
# [2010, 1, '눈 덮힌 불암초등학교']
# [2010, 1, '눈 내린 서울, 빙판길 조심하세요']
# [2010, 1, '눈 덮힌 차량들']
# [2010, 1, "'많이도 왔네'"]
# [2010, 1, '눈덮힌 설악산 대청봉']
# [2010, 1, '&lt;환경&gt; 태즈메이니아데빌의 암 원인 발견']
# [2010, 1, '&lt;내주날씨&gt; 다시 한파…초반 흐리고 눈ㆍ비']
# [2010, 1, '하루종일 오려나']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '조심 조심']
# [2010, 1, '운전 조심하세요']
# [2010, 1, '눈이 많이 오네']
# [2010, 1, '아침 데이트']
# [2010, 1, '국내 첫 발견 수지밀구멍버섯 자실체 사진']
# [2010, 1, '신종 주홍털구름버섯 자실체 사진']
# [2010, 1, '경인년 새해를 맞는 안성시민들']
# [2010, 1, '2일 중부·경북지방에 눈…주말에도 추워']
# [2010, 1, '세계 최대 전자쇼 美‘CES’ 7일 개막']
# [2010, 1, '새해 연휴 도로 정체-이번 주 내내 강추위']
# [2010, 1, '[날씨_4일(월)] 아침 최저 영하11도']
# [2010, 1, '4일 중부지방 큰 눈']
# [2010, 1, '대구경북 추운 날씨속 연휴 마지막 즐겨']
# [2010, 1, '4일 전국 눈…쌀쌀한 날씨 계속']
# [2010, 1, '이층 썰매']
# [2010, 1, '썰매는 엎드려 타야 더 재밌어요']
# [2010, 1, '앙증맞은 썰매타는 아이들']
# [2010, 1, '신나는 엎드려 썰매타기']
# [2010, 1, '아빠가 끌어주는   썰매']
# [2010, 1, '무릎이 털털털']
# [2010, 1, '얼음에서 타면 모든것이 썰매']
# [2010, 1, '재밌는 형제의 비닐썰매']
# [2010, 1, '엄마 아빠와  썰매타기']
# [2010, 1, '썰매장에서 동력은  반칙']
# [2010, 1, '바퀴가 구르는 썰매여요']
# [2010, 1, "'우리 썰매가 최고다'"]
# [2010, 1, '아빠도 한번 타보자']
# [2010, 1, '김제시, 고품질쌀 생산법 책자로 알린다']
# [2010, 1, '잠자는 오리들']
